# %%
from roboflow import Roboflow

rf = Roboflow(api_key="oGmc45NtMFw3zKqZ3y5n")
project = rf.workspace("julios-workspace-lodyj").project("My First Project")
dataset = project.version(1).download("yolov8")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=undefined&ref=undefined
# loading Roboflow workspace...
# ---------------------------------------------------------------------------
# RoboflowError                             Traceback (most recent call last)
# Cell In[1], line 4
#       1 from roboflow import Roboflow
#       3 rf = Roboflow(api_key="TU_API_KEY")
# ----> 4 project = rf.workspace("julios-workspace-lodyj").project("My First Project")
#       5 dataset = project.version(1).download("yolov8")
#
# File c:\Users\Julio\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\roboflow\__init__.py:244, in Roboflow.workspace(self, the_workspace)
#     242 if self.api_key:  # Check if api_key was passed during __init__
#     243     api_key = self.api_key
# --> 244     list_projects = rfapi.get_workspace(api_key, the_workspace)
#     245     return Workspace(list_projects, api_key, the_workspace, self.model_format)
# ...
